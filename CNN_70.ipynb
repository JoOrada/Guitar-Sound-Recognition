# %%
#! pip install pydub
#! pip install noisereduce

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.lite as tflite
from tensorflow.keras import layers
from tensorflow.keras import models

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display

#Import for the dataset
#import opendatasets as od

import os
#import tensorflow_model_optimization as tfmot

from pydub import AudioSegment
import noisereduce as nr


import librosa
from scipy.io import wavfile
import soundfile as sf
import wave

import wave
import contextlib

from librosa import load
from librosa.util import fix_length

#import argparse
# Out:
# C:\Users\joana\anaconda3\envs\p3_7_11\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
#od.download("https://www.kaggle.com/fabianavinci/guitar-chords-v2")

# %%
############################## Parameters ##############################
# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

freq=44100

# %%
############################## Dataset ##############################
dataset_version=3

# No noise reduc everything at 44100
data_dir = 'guitar-chords-v3_44100'


'''
#!!!!!! When we have the right datase we change it to the code at the end
zip_path = tf.keras.utils.get_file(
        origin="https://www.kaggle.com/fabianavinci/guitar-chords-v3",
        fname='guitar-chords-v3.zip',
        extract=True,
        cache_dir='.', cache_subdir='data')
'''


############################ Labels for the dataset ############################
chords = np.array(tf.io.gfile.listdir(str(data_dir+ '/Training/')))
chords = chords[chords != 'README.md']
print('Chords:', chords)
# Out:
# Chords: ['Am' 'Bb' 'Bdim' 'C' 'Dm' 'Em' 'F' 'G']

# %%
########################### MAX DURATION OF AUDIOS  ############################
'''max_duration=0 
set_type= "Training"
for i in chords:
    directory=str(f'{data_dir}/{set_type}/{i}/')
    for file in os.listdir(directory):               
        audio, sampling_rate = librosa.load(f'{directory}/{file}', sr=freq, mono=True)
        duration=librosa.get_duration(y=audio, sr=freq)
        if duration> max_duration:
            max_duration= duration
        
print(f"Audio duration: {max_duration}")
'''
# Out:
# 'max_duration=0 \nset_type= "Training"\nfor i in chords:\n    directory=str(f\'{data_dir}/{set_type}/{i}/\')\n    for file in os.listdir(directory):               \n        audio, sampling_rate = librosa.load(f\'{directory}/{file}\', sr=freq, mono=True)\n        duration=librosa.get_duration(y=audio, sr=freq)\n        if duration> max_duration:\n            max_duration= duration\n        \nprint(f"Audio duration: {max_duration}")\n'

# %%
def transform_origianl_samples(chords, set_type, freq, dataset_version, data_dir):
    required_audio_size = 8
    print(f'Required audio size: {required_audio_size}' )

    max_shape=0
    print(f'Data set version: {dataset_version}')
    set_type="Training"
    for i in chords:
    # Directory: Original dataset without transformations 
        directory=str(f'{data_dir}/{set_type}/{i}/')


        for file in os.listdir(directory):       

            audio, sampling_rate = librosa.load(f'{directory}/{file}', sr=freq, mono=True)
            # perform noise reduction
            #reduced_noise = nr.reduce_noise(y=audio, sr=sampling_rate)
            #print(type(reduced_noise))
            #print("Audio tipo", audio.shape)
            shape_audio=audio.shape
            #padded_audio = fix_length(audio, size=8*sf) # array size is required_audio_size*sampling frequency

            if shape_audio[0]> max_shape:
                max_shape= shape_audio[0]

            sf.write(directory+ f"{file}",  audio, sampling_rate)
    
    return max_shape

    print(f"Audio transformations: Frequency - {freq}     Folder -  {set_type}    Path -{directory}  ")
    print(f"MAX AUDIO SHAPE = {max_shape}  ")

# %%
print(freq)
print(data_dir)
# Out:
# 44100
# guitar-chords-v3_44100

# %%
set_type="Training"
max_shape = transform_origianl_samples(chords, set_type, freq, dataset_version, data_dir )
set_type="Test"
#transform_origianl_samples(chords, set_type, freq, dataset_version, data_dir )
# Out:
# Required audio size: 8
# Data set version: 3

# %%
############################ Dataset split ############################
def split_dataset(set_type, chords, data_dir):

    filenames=  tf.io.gfile.glob(str(data_dir) + f'/{set_type}/*/*')

    if set_type=="Training":
        filenames=tf.random.shuffle(filenames)

    filenames_samples=len(filenames)
    print(f"########################## {set_type} information ##############################")
    print(f'{set_type} - Number of total examples:', filenames_samples)
    print(f'{set_type} - Number of examples per label:',
        len(tf.io.gfile.listdir(str(data_dir+ f'/{set_type}/'+ chords[0]))))
    print(f'{set_type} - Example file tensor:', filenames[1])
    
    return filenames,filenames_samples

# %%
############################ Training ############################
set_type="Training"
training_filenames,train_num_samples = split_dataset(set_type, chords, data_dir )

############################ Test ############################
set_type="Test"
test_filenames, _ = split_dataset(set_type, chords, data_dir )
# Out:
# ########################## Training information ##############################
# Training - Number of total examples: 1447
# Training - Number of examples per label: 180
# Training - Example file tensor: tf.Tensor(b'guitar-chords-v3_44100\\Training\\F\\F_AcousticGuitar_RodrigoMercador_4.wav', shape=(), dtype=string)
# ########################## Test information ##############################
# Test - Number of total examples: 320
# Test - Number of examples per label: 40
# Test - Example file tensor: guitar-chords-v3_44100\Test\Dm\Dm_AcusticPlug26_2.wav

# %%
############################ Validation set ############################
val_filenames = training_filenames[int(train_num_samples*0.9):]
len_val=len(val_filenames)
print("########################## Validation information ##############################")
print('Validation - Number of total examples:',len_val )
# Out:
# ########################## Validation information ##############################
# Validation - Number of total examples: 145

# %%
class SignalGenerator:
    def __init__(self, labels, sampling_rate, frame_length, frame_step, max_shape, batch_size,
            num_mel_bins=None, lower_frequency=None, upper_frequency=None,
            num_coefficients=None, mfcc=False,plot=False):
        self.labels = labels
        self.sampling_rate = sampling_rate
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.num_mel_bins = num_mel_bins
        self.lower_frequency = lower_frequency
        self.upper_frequency = upper_frequency
        self.num_coefficients = num_coefficients
        num_spectrogram_bins = (frame_length) // 2 + 1
        self.plot=plot
        self.max_shape=max_shape
        self.batch_size=batch_size

        if mfcc is True:
            self.linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
                    self.num_mel_bins, num_spectrogram_bins, self.sampling_rate,
                    self.lower_frequency, self.upper_frequency)
            self.preprocess = self.preprocess_with_mfcc
        else:
            self.preprocess = self.preprocess_with_stft

    def read(self, file_path):
        parts = tf.strings.split(file_path, os.path.sep)
        label = parts[-2]
        print(f"Parts:{parts}")
        label_id = tf.argmax(label == self.labels)
        audio_binary = tf.io.read_file(file_path)
        audio, _ = tf.audio.decode_wav(audio_binary)
        audio = tf.squeeze(audio, axis=1)
        
        return audio, label_id

       
    def pad(self, audio):
        #print(self.sampling_rate)
        input_len = max_shape
        audio = audio[:input_len]
        print(f"Tfshape {tf.shape(audio)}")
        zero_padding = tf.zeros( self.max_shape - tf.shape(audio), dtype=tf.float32)
        audio = tf.concat([audio, zero_padding], 0)
        audio.set_shape([max_shape])

        return audio

    def get_spectrogram(self, audio):
        stft = tf.signal.stft(audio, frame_length=self.frame_length,
                frame_step=self.frame_step, fft_length=self.frame_length)
        spectrogram = tf.abs(stft)

        return spectrogram

    def get_mfccs(self, spectrogram):
        mel_spectrogram = tf.tensordot(spectrogram,
                self.linear_to_mel_weight_matrix, 1)
        log_mel_spectrogram = tf.math.log(mel_spectrogram + 1.e-6)
        mfccs = tf.signal.mfccs_from_log_mel_spectrograms(log_mel_spectrogram)
        mfccs = mfccs[..., :self.num_coefficients]

        return mfccs

    def preprocess_with_stft(self, file_path, plot):
        print(plot)
        audio, label = self.read(file_path)
        audio = self.pad(audio)
        spectrogram = self.get_spectrogram(audio)
        spectrogram = tf.expand_dims(spectrogram, -1)
        
        if plot == False:
            spectrogram = tf.image.resize(spectrogram, [32, 32])

        return spectrogram, label

    def preprocess_with_mfcc(self, file_path):
        audio, label = self.read(file_path)
        audio = self.pad(audio)
        spectrogram = self.get_spectrogram(audio)
        mfccs = self.get_mfccs(spectrogram)
        mfccs = tf.expand_dims(mfccs, -1)

        return mfccs, label

    def make_dataset(self, files, train,batch_size):
        ds = tf.data.Dataset.from_tensor_slices(files)
        ds = ds.map(self.preprocess, num_parallel_calls=4)
        ds = ds.batch(batch_size)
        ds = ds.cache()
        if train is True:
            ds = ds.shuffle(100, reshuffle_each_iteration=True)

        return ds
    
    def read_waveform(self, file_path ):
        parts = tf.strings.split(file_path, os.path.sep)
        label = parts[-2]
        print(f"Parts:{parts}")
        label_id = tf.argmax(label == self.labels)
        audio_binary = tf.io.read_file(file_path)
        audio, _ = tf.audio.decode_wav(audio_binary)
        #audio = tf.squeeze(audio, axis=1)
        
        return audio, label
    
    #Function to get the spectogram
    def get_spectrogram_waveform(self, waveform):
        # Zero-padding for an audio waveform with less than 16,000 samples.
        ############# TRY a different input len ############################
        #input_len = freq
        #waveform = waveform[:input_len]
        zero_padding = tf.zeros(
                      [self.sampling_rate] - tf.shape(waveform), dtype=tf.float32)
        # Cast the waveform tensors' dtype to float32.
        waveform = tf.cast(waveform, dtype=tf.float32)
        # Concatenate the waveform with `zero_padding`, which ensures all audio
        # clips are of the same length.
        equal_length = tf.concat([waveform, zero_padding], 0)
        waveform=waveform.set_shape([self.sampling_rate])
        
        # Convert the waveform to a spectrogram via a STFT.
        spectrogram = tf.signal.stft(
          equal_length, self.frame_length, self.frame_step)
        # Obtain the magnitude of the STFT.
        spectrogram = tf.abs(spectrogram)

        # Add a `channels` dimension, so that the spectrogram can be used
        # as image-like input data with convolution layers (which expect
        # shape (`batch_size`, `height`, `width`, `channels`).
        #spectrogram = spectrogram[..., tf.newaxis]
        return spectrogram

# %%
STFT_OPTIONS = {'frame_length': 256, 'frame_step': 128, 'mfcc': False , 'max_shape': max_shape }
MFCC_OPTIONS = {'frame_length': 640, 'frame_step': 320, 'mfcc': True,
        'lower_frequency': 20, 'upper_frequency': 4000, 'num_mel_bins': 40,
        'num_coefficients': 10, 'max_shape': max_shape }
mfcc=True

if mfcc is True:
    options = MFCC_OPTIONS
    strides = [2, 1]
else:
    options = STFT_OPTIONS
    strides = [2, 2]
    
    
generator = SignalGenerator(chords, freq,batch_size=32, **options)
train_ds = generator.make_dataset(training_filenames, True,batch_size=32)
val_ds = generator.make_dataset(val_filenames, False ,batch_size=32)
test_ds = generator.make_dataset(test_filenames, False,batch_size=32)
# Out:
# Parts:Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)
# Tfshape Tensor("Shape:0", shape=(1,), dtype=int32)
# Parts:Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)
# Tfshape Tensor("Shape:0", shape=(1,), dtype=int32)
# Parts:Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)
# Tfshape Tensor("Shape:0", shape=(1,), dtype=int32)

# %%
#For a better performance and OPTIMIZATION
AUTOTUNE = tf.data.AUTOTUNE #Optimize the number of parellel calls

train_files_ds = tf.data.Dataset.from_tensor_slices(training_filenames)
train_waveform_ds = train_files_ds.map(
    map_func=generator.read_waveform,
    num_parallel_calls=AUTOTUNE)
# Out:
# Parts:Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)

# %%
############################ Data exploration ############################

rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))

for i, (audio, label) in enumerate(train_waveform_ds.take(n)):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    ax.plot(audio.numpy())
    ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
    label = label.numpy().decode('utf-8')
    ax.set_title(label)

plt.show()

# %%
#Visualization of the spectogram
def plot_spectrogram(spectrogram, ax):
    if len(spectrogram.shape) > 2:
        assert len(spectrogram.shape) == 3
        spectrogram = np.squeeze(spectrogram, axis=-1)
    # Convert the frequencies to log scale and transpose, so that the time is
    # represented on the x-axis (columns).
    # Add an epsilon to avoid taking a log of zero.
    log_spec = np.log(spectrogram.T + np.finfo(float).eps)
    height = log_spec.shape[0]
    width = log_spec.shape[1]


    X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
    Y = range(height)
    ax.pcolormesh(X, Y, log_spec)

# %%
#STFT
for waveform, label in train_waveform_ds.take(1):
    label = label.numpy().decode('utf-8')
    spectrogram,_ = generator.preprocess_with_stft(training_filenames[0],plot=True)
# Out:
# True
# Parts:[b'guitar-chords-v3_44100' b'Training' b'Dm' b'Dm_electric_Isabel_4.wav']
# Tfshape [214021]

# %%
print(training_filenames[0].numpy())
spectrogram,_ = generator.preprocess_with_stft(training_filenames[0],plot=True)
# Out:
# b'guitar-chords-v3_44100\\Training\\Dm\\Dm_electric_Isabel_4.wav'
# True
# Parts:[b'guitar-chords-v3_44100' b'Training' b'Dm' b'Dm_electric_Isabel_4.wav']
# Tfshape [214021]

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, len(waveform)  ])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
axes[1].set_xlim([0,len(waveform)])
plt.show()

# %%
############################ Parameters for the Model ############################

input_shape = spectrogram.shape
output_shape = len(chords)
print(input_shape)
# Out:
# (2251, 10, 1)

# %%
############################ MODEL ############################
cnn = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=input_shape, filters=128, kernel_size=[3,3], strides=strides, use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Conv2D(input_shape=input_shape, filters=128, kernel_size=[3,3], strides=[1,1], use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Conv2D(input_shape=input_shape, filters=128, kernel_size=[3,3], strides=[1,1], use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(units = 8)
])

dcnn = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=input_shape, filters=256, kernel_size=[3,3], strides=strides, use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.DepthwiseConv2D(kernel_size=[3, 3], strides=[1, 1], use_bias=False),
    tf.keras.layers.Conv2D(filters=128, kernel_size=[1,1], strides=[1,1], use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.DepthwiseConv2D(kernel_size=[3, 3], strides=[1, 1], use_bias=False),
    tf.keras.layers.Conv2D(filters=64, kernel_size=[1,1], strides=[1,1], use_bias=False),
    tf.keras.layers.BatchNormalization(momentum=0.1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(units = 8)
])

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.optimizers.Adam()
metrics = [tf.keras.metrics.SparseCategoricalAccuracy()]

# %%
model=cnn
model.compile(loss = loss, optimizer = optimizer, metrics = metrics)



history= model.fit(train_ds, validation_data=val_ds, epochs=50)
                   #callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2))

model.summary()
# Out:
# Epoch 1/50
# 46/46 [==============================] - 236s 2s/step - loss: 1.9452 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.7559 - val_sparse_categorical_accuracy: 0.5241
# Epoch 2/50
# 46/46 [==============================] - 79s 2s/step - loss: 1.7104 - sparse_categorical_accuracy: 0.4692 - val_loss: 1.6356 - val_sparse_categorical_accuracy: 0.5310
# Epoch 3/50
# 46/46 [==============================] - 79s 2s/step - loss: 1.5907 - sparse_categorical_accuracy: 0.5003 - val_loss: 1.5535 - val_sparse_categorical_accuracy: 0.4828
# Epoch 4/50
# 46/46 [==============================] - 80s 2s/step - loss: 1.5053 - sparse_categorical_accuracy: 0.5577 - val_loss: 1.4395 - val_sparse_categorical_accuracy: 0.5448
# Epoch 5/50
# 46/46 [==============================] - 80s 2s/step - loss: 1.4626 - sparse_categorical_accuracy: 0.5556 - val_loss: 1.4067 - val_sparse_categorical_accuracy: 0.5793
# Epoch 6/50
# 46/46 [==============================] - 78s 2s/step - loss: 1.3980 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.3293 - val_sparse_categorical_accuracy: 0.5586
# Epoch 7/50
# 46/46 [==============================] - 87s 2s/step - loss: 1.3493 - sparse_categorical_accuracy: 0.5819 - val_loss: 1.2866 - val_sparse_categorical_accuracy: 0.5862
# Epoch 8/50
# 46/46 [==============================] - 84s 2s/step - loss: 1.3330 - sparse_categorical_accuracy: 0.5867 - val_loss: 1.2666 - val_sparse_categorical_accuracy: 0.6138
# Epoch 9/50
# 46/46 [==============================] - 96s 2s/step - loss: 1.2930 - sparse_categorical_accuracy: 0.6185 - val_loss: 1.2190 - val_sparse_categorical_accuracy: 0.6138
# Epoch 10/50
# 46/46 [==============================] - 99s 2s/step - loss: 1.2495 - sparse_categorical_accuracy: 0.6220 - val_loss: 1.2064 - val_sparse_categorical_accuracy: 0.6069
# Epoch 11/50
# 46/46 [==============================] - 98s 2s/step - loss: 1.2310 - sparse_categorical_accuracy: 0.6192 - val_loss: 1.2266 - val_sparse_categorical_accuracy: 0.6000
# Epoch 12/50
# 46/46 [==============================] - 101s 2s/step - loss: 1.2116 - sparse_categorical_accuracy: 0.6240 - val_loss: 1.1612 - val_sparse_categorical_accuracy: 0.6276
# Epoch 13/50
# 46/46 [==============================] - 92s 2s/step - loss: 1.1804 - sparse_categorical_accuracy: 0.6365 - val_loss: 1.1608 - val_sparse_categorical_accuracy: 0.6345
# Epoch 14/50
# 46/46 [==============================] - 90s 2s/step - loss: 1.1808 - sparse_categorical_accuracy: 0.6206 - val_loss: 1.1542 - val_sparse_categorical_accuracy: 0.6345
# Epoch 15/50
# 46/46 [==============================] - 93s 2s/step - loss: 1.1436 - sparse_categorical_accuracy: 0.6455 - val_loss: 1.1069 - val_sparse_categorical_accuracy: 0.6414
# Epoch 16/50
# 46/46 [==============================] - 101s 2s/step - loss: 1.1210 - sparse_categorical_accuracy: 0.6399 - val_loss: 1.1143 - val_sparse_categorical_accuracy: 0.6483
# Epoch 17/50
# 46/46 [==============================] - 103s 2s/step - loss: 1.1102 - sparse_categorical_accuracy: 0.6406 - val_loss: 1.1267 - val_sparse_categorical_accuracy: 0.6276
# Epoch 18/50
# 46/46 [==============================] - 91s 2s/step - loss: 1.0779 - sparse_categorical_accuracy: 0.6558 - val_loss: 1.0452 - val_sparse_categorical_accuracy: 0.6897
# Epoch 19/50
# 46/46 [==============================] - 91s 2s/step - loss: 1.0816 - sparse_categorical_accuracy: 0.6551 - val_loss: 1.0403 - val_sparse_categorical_accuracy: 0.6690
# Epoch 20/50
# 46/46 [==============================] - 90s 2s/step - loss: 1.0800 - sparse_categorical_accuracy: 0.6572 - val_loss: 1.0870 - val_sparse_categorical_accuracy: 0.6414
# Epoch 21/50
# 46/46 [==============================] - 89s 2s/step - loss: 1.0411 - sparse_categorical_accuracy: 0.6676 - val_loss: 1.0391 - val_sparse_categorical_accuracy: 0.6483
# Epoch 22/50
# 46/46 [==============================] - 96s 2s/step - loss: 1.0211 - sparse_categorical_accuracy: 0.6752 - val_loss: 1.0252 - val_sparse_categorical_accuracy: 0.6552
# Epoch 23/50
# 46/46 [==============================] - 85s 2s/step - loss: 1.0196 - sparse_categorical_accuracy: 0.6697 - val_loss: 0.9732 - val_sparse_categorical_accuracy: 0.7241
# Epoch 24/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.9946 - sparse_categorical_accuracy: 0.6793 - val_loss: 1.0079 - val_sparse_categorical_accuracy: 0.6759
# Epoch 25/50
# 46/46 [==============================] - 92s 2s/step - loss: 1.0006 - sparse_categorical_accuracy: 0.6669 - val_loss: 1.0434 - val_sparse_categorical_accuracy: 0.6828
# Epoch 26/50
# 46/46 [==============================] - 91s 2s/step - loss: 0.9695 - sparse_categorical_accuracy: 0.6800 - val_loss: 0.9388 - val_sparse_categorical_accuracy: 0.7034
# Epoch 27/50
# 46/46 [==============================] - 87s 2s/step - loss: 0.9603 - sparse_categorical_accuracy: 0.6849 - val_loss: 0.9070 - val_sparse_categorical_accuracy: 0.7172
# Epoch 28/50
# 46/46 [==============================] - 84s 2s/step - loss: 0.9385 - sparse_categorical_accuracy: 0.6980 - val_loss: 0.9874 - val_sparse_categorical_accuracy: 0.6828
# Epoch 29/50
# 46/46 [==============================] - 85s 2s/step - loss: 0.9210 - sparse_categorical_accuracy: 0.6994 - val_loss: 1.0050 - val_sparse_categorical_accuracy: 0.6621
# Epoch 30/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.9513 - sparse_categorical_accuracy: 0.6876 - val_loss: 0.9579 - val_sparse_categorical_accuracy: 0.6828
# Epoch 31/50
# 46/46 [==============================] - 91s 2s/step - loss: 0.9165 - sparse_categorical_accuracy: 0.6904 - val_loss: 0.9619 - val_sparse_categorical_accuracy: 0.7103
# Epoch 32/50
# 46/46 [==============================] - 90s 2s/step - loss: 0.9220 - sparse_categorical_accuracy: 0.6959 - val_loss: 0.9138 - val_sparse_categorical_accuracy: 0.6966
# Epoch 33/50
# 46/46 [==============================] - 91s 2s/step - loss: 0.8893 - sparse_categorical_accuracy: 0.7077 - val_loss: 0.8632 - val_sparse_categorical_accuracy: 0.7241
# Epoch 34/50
# 46/46 [==============================] - 90s 2s/step - loss: 0.8625 - sparse_categorical_accuracy: 0.7173 - val_loss: 0.8679 - val_sparse_categorical_accuracy: 0.7241
# Epoch 35/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.8504 - sparse_categorical_accuracy: 0.7263 - val_loss: 0.8588 - val_sparse_categorical_accuracy: 0.7310
# Epoch 36/50
# 46/46 [==============================] - 89s 2s/step - loss: 0.8313 - sparse_categorical_accuracy: 0.7388 - val_loss: 0.9387 - val_sparse_categorical_accuracy: 0.7034
# Epoch 37/50
# 46/46 [==============================] - 101s 2s/step - loss: 0.7843 - sparse_categorical_accuracy: 0.7498 - val_loss: 0.8583 - val_sparse_categorical_accuracy: 0.7379
# Epoch 38/50
# 46/46 [==============================] - 94s 2s/step - loss: 0.7744 - sparse_categorical_accuracy: 0.7595 - val_loss: 0.8642 - val_sparse_categorical_accuracy: 0.7172
# Epoch 39/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.7413 - sparse_categorical_accuracy: 0.7650 - val_loss: 0.7501 - val_sparse_categorical_accuracy: 0.7793
# Epoch 40/50
# 46/46 [==============================] - 89s 2s/step - loss: 0.7094 - sparse_categorical_accuracy: 0.7816 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.7448
# Epoch 41/50
# 46/46 [==============================] - 89s 2s/step - loss: 0.6957 - sparse_categorical_accuracy: 0.7816 - val_loss: 0.8077 - val_sparse_categorical_accuracy: 0.7586
# Epoch 42/50
# 46/46 [==============================] - 89s 2s/step - loss: 0.6032 - sparse_categorical_accuracy: 0.8072 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.8069
# Epoch 43/50
# 46/46 [==============================] - 85s 2s/step - loss: 0.5545 - sparse_categorical_accuracy: 0.8376 - val_loss: 0.6017 - val_sparse_categorical_accuracy: 0.7655
# Epoch 44/50
# 46/46 [==============================] - 90s 2s/step - loss: 0.5366 - sparse_categorical_accuracy: 0.8397 - val_loss: 0.5600 - val_sparse_categorical_accuracy: 0.8345
# Epoch 45/50
# 46/46 [==============================] - 90s 2s/step - loss: 0.5153 - sparse_categorical_accuracy: 0.8514 - val_loss: 0.5606 - val_sparse_categorical_accuracy: 0.8207
# Epoch 46/50
# 46/46 [==============================] - 92s 2s/step - loss: 0.4699 - sparse_categorical_accuracy: 0.8563 - val_loss: 0.5127 - val_sparse_categorical_accuracy: 0.8345
# Epoch 47/50
# 46/46 [==============================] - 92s 2s/step - loss: 0.4522 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.5864 - val_sparse_categorical_accuracy: 0.7862
# Epoch 48/50
# 46/46 [==============================] - 93s 2s/step - loss: 0.4455 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.4764 - val_sparse_categorical_accuracy: 0.8621
# Epoch 49/50
# 46/46 [==============================] - 89s 2s/step - loss: 0.4272 - sparse_categorical_accuracy: 0.8867 - val_loss: 0.4941 - val_sparse_categorical_accuracy: 0.8345
# Epoch 50/50
# 46/46 [==============================] - 88s 2s/step - loss: 0.4023 - sparse_categorical_accuracy: 0.8874 - val_loss: 0.5307 - val_sparse_categorical_accuracy: 0.8345
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1125, 8, 128)      1152
#
#  batch_normalization (BatchN  (None, 1125, 8, 128)     512
#  ormalization)
#
#  re_lu (ReLU)                (None, 1125, 8, 128)      0
#
#  conv2d_1 (Conv2D)           (None, 1123, 6, 128)      147456
#
#  batch_normalization_1 (Batc  (None, 1123, 6, 128)     512
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 1123, 6, 128)      0
#
#  conv2d_2 (Conv2D)           (None, 1121, 4, 128)      147456
#
#  batch_normalization_2 (Batc  (None, 1121, 4, 128)     512
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 1121, 4, 128)      0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 8)                 1032
#
# =================================================================
# Total params: 298,632
# Trainable params: 297,864
# Non-trainable params: 768
# _________________________________________________________________

# %%
#PLOT loss metric to evaluate
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
metrics = history.history
plt.plot(history.epoch, metrics['sparse_categorical_accuracy'], metrics['val_sparse_categorical_accuracy'])
plt.legend(['sparse_categorical_accuracy', 'val_sparse_categorical_accuracy'])
plt.show()

# %%
model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 44s 4s/step - loss: 0.9144 - sparse_categorical_accuracy: 0.6969
# [0.9143819808959961, 0.6968749761581421]

# %%
####################### CONFUSION MATRIX ##########################
test_audio = []
test_labels = []

for audio, label in test_ds:
    #test_audio.append(audio.numpy())
    test_labels.append(label.numpy())

test_labels = np.array(test_labels)

y_pred = np.argmax(model.predict(test_ds), axis=1)
y_true = test_labels

y_true=y_true.reshape(320,)

# %%
#Transformation to tensor - 1D 

confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=chords,
            yticklabels=chords,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
